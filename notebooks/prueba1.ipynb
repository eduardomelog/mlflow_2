# %%
# !pip install setuptools

# %%
import mlflow
import numpy as np
import os

# %%
# Forzamos MLflow a usar un path local y relativo al repo
mlflow.set_tracking_uri("file:../mlruns")

# Creamos / usamos el experimento
mlflow.set_experiment("experimento_2")
# Out:
# /Users/eduardo.melo/.pyenv/versions/3.12.2/lib/python3.12/site-packages/mlflow/tracking/_tracking_service/utils.py:178: FutureWarning: The filesystem tracking backend (e.g., './mlruns') will be deprecated in February 2026. Consider transitioning to a database backend (e.g., 'sqlite:///mlflow.db') to take advantage of the latest MLflow features. See https://github.com/mlflow/mlflow/issues/18534 for more details and migration guidance. For migrating existing data, https://github.com/mlflow/mlflow-export-import can be used.
#   return FileStore(store_uri, store_uri)
# 2026/02/09 22:37:10 INFO mlflow.tracking.fluent: Experiment with name 'experimento_2' does not exist. Creating a new experiment.
# <Experiment: artifact_location='file:///Users/eduardo.melo/Documents/lalo/github_repos/mlflow_2/notebooks/../mlruns/183123290460502020', creation_time=1770698230633, experiment_id='183123290460502020', last_update_time=1770698230633, lifecycle_stage='active', name='experimento_2', tags={}>

# %%
for i in range(3):
    with mlflow.start_run(run_name=f"run_{i+1}"):

        lr = np.random.uniform(0.0001, 0.1)
        batch_size = np.random.choice([16, 32, 64])
        accuracy = np.random.uniform(0.7, 0.95)

        mlflow.log_param("learning_rate", lr)
        mlflow.log_param("batch_size", batch_size)
        mlflow.log_metric("accuracy", accuracy)

        print(f"Run {i+1} registrado")
# Out:
# Run 1 registrado
# Run 2 registrado
# Run 3 registrado
